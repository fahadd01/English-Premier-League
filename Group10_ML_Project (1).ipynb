# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
y1 = pd.read_csv('2000-01.csv')
y2 = pd.read_csv('2001-02.csv')
y3 = pd.read_csv('2002-03.csv')
y4 = pd.read_csv('2003-04.csv')
y5 = pd.read_csv('2004-05.csv')
y6 = pd.read_csv('2005-06.csv')
y7 = pd.read_csv('2006-07.csv')
y8 = pd.read_csv('2007-08.csv')
y9 = pd.read_csv('2008-09.csv')
y10 = pd.read_csv('2009-10.csv')
y11 = pd.read_csv('2010-11.csv')
y12 = pd.read_csv('2011-12.csv')
y13 = pd.read_csv('2012-13.csv')
y14 = pd.read_csv('2013-14.csv')
y15 = pd.read_csv('2014-15.csv')
y16 = pd.read_csv('2015-16.csv')
y17 = pd.read_csv('2016-17.csv')
y18 = pd.read_csv('2017-18.csv')
y19 = pd.read_csv('2018-19.csv')
y20 = pd.read_csv('2019-20.csv')

# %%
y17
# Out:
#     Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  13/08/16         Burnley         Swansea     0     1   A     0     0
# 1    E0  13/08/16  Crystal Palace       West Brom     0     1   A     0     0
# 2    E0  13/08/16         Everton       Tottenham     1     1   D     1     0
# 3    E0  13/08/16            Hull       Leicester     2     1   H     1     0
# 4    E0  13/08/16        Man City      Sunderland     2     1   H     1     0
# ..   ..       ...             ...             ...   ...   ...  ..   ...   ...
# 375  E0  21/05/17       Liverpool   Middlesbrough     3     0   H     1     0
# 376  E0  21/05/17      Man United  Crystal Palace     2     0   H     2     0
# 377  E0  21/05/17     Southampton           Stoke     0     1   A     0     0
# 378  E0  21/05/17         Swansea       West Brom     2     1   H     0     1
# 379  E0  21/05/17         Watford        Man City     0     5   A     0     4
#
#     HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA   PSCH  \
# 0     D  ...     1.61    32  -0.25     2.13     2.06     1.86     1.81   2.79
# 1     D  ...     1.52    33  -0.50     2.07     2.00     1.90     1.85   2.25
# 2     H  ...     1.77    32   0.25     1.91     1.85     2.09     2.00   3.64
# 3     H  ...     1.67    31   0.25     2.35     2.26     2.03     1.67   4.68
# 4     H  ...     2.48    34  -1.50     1.81     1.73     2.20     2.14   1.25
# ..   ..  ...      ...   ...    ...      ...      ...      ...      ...    ...
# 375   H  ...     2.73    18  -2.50     2.02     1.97     1.95     1.90   1.15
# 376   H  ...     1.81    19  -0.25     2.19     2.11     1.85     1.79   2.35
# 377   D  ...     2.01    18  -0.75     2.03     1.98     1.93     1.88   1.64
# 378   A  ...     1.98    19  -0.50     2.11     2.06     1.86     1.82   2.29
# 379   A  ...     2.80    18   1.75     1.99     1.94     2.00     1.93  18.00
#
#       PSCD   PSCA
# 0     3.16   2.89
# 1     3.15   3.86
# 2     3.54   2.16
# 3     3.50   1.92
# 4     6.50  14.50
# ..     ...    ...
# 375  10.50  19.09
# 376   3.38   3.35
# 377   4.37   5.53
# 378   3.45   3.40
# 379   9.70   1.16
#
# [380 rows x 65 columns]

# %%
raw_data_1 = y1[['Date', 'HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_1.shape)
raw_data_2 = y2[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_2.shape)
raw_data_3 = y3[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_3.shape)
raw_data_4 = y4[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_4.shape)
raw_data_5 = y5[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_5.shape)
raw_data_6 = y6[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_6.shape)
raw_data_7 = y7[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_7.shape)
raw_data_8 = y8[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_8.shape)
raw_data_9 = y9[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_9.shape)
raw_data_10 = y10[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_10.shape)
raw_data_11 = y11[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_11.shape)
raw_data_12 = y12[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_12.shape)
raw_data_13 = y13[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_13.shape)
raw_data_14 = y14[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_14.shape)
raw_data_15 = y15[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_15.shape)
raw_data_16 = y16[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_16.shape)
raw_data_17 = y17[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_17.shape)
raw_data_18 = y18[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_18.shape)
raw_data_19 = y19[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_19.shape)
raw_data_20 = y20[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]
print(raw_data_20.shape)

#extracting raw data
# Out:
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (380, 21)
# (160, 21)
# (260, 21)

# %%
arr = [y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18,y19,y20]

for i in range(len(arr)):
    print(arr[i].shape)
    
for i in range(len(arr)):
    print("\n",i)
    print(arr[i].columns.values)
# Out:
# (380, 28)
# (380, 28)
# (380, 23)
# (380, 23)
# (380, 23)
# (380, 23)
# (380, 23)
# (380, 23)
# (380, 23)
# (380, 71)
# (380, 71)
# (380, 71)
# (380, 71)
# (380, 65)
# (380, 65)
# (380, 62)
# (380, 65)
# (380, 65)
# (160, 62)
# (260, 106)
#
#  0
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Attendance' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HHW' 'AHW' 'HC' 'AC'
#  'HF' 'AF' 'HO' 'AO' 'HY' 'AY' 'HR' 'AR']
#
#  1
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Attendance' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HHW' 'AHW' 'HC' 'AC'
#  'HF' 'AF' 'HO' 'AO' 'HY' 'AY' 'HR' 'AR']
#
#  2
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  3
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  4
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  5
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  6
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  7
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  8
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR']
#
#  9
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'GBH' 'GBD' 'GBA' 'IWH'
#  'IWD' 'IWA' 'LBH' 'LBD' 'LBA' 'SBH' 'SBD' 'SBA' 'WHH' 'WHD' 'WHA' 'SJH'
#  'SJD' 'SJA' 'VCH' 'VCD' 'VCA' 'BSH' 'BSD' 'BSA' 'Bb1X2' 'BbMxH' 'BbAvH'
#  'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5'
#  'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']
#
#  10
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'GBH' 'GBD' 'GBA' 'IWH'
#  'IWD' 'IWA' 'LBH' 'LBD' 'LBA' 'SBH' 'SBD' 'SBA' 'WHH' 'WHD' 'WHA' 'SJH'
#  'SJD' 'SJA' 'VCH' 'VCD' 'VCA' 'BSH' 'BSD' 'BSA' 'Bb1X2' 'BbMxH' 'BbAvH'
#  'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5'
#  'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']
#
#  11
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'GBH' 'GBD' 'GBA' 'IWH'
#  'IWD' 'IWA' 'LBH' 'LBD' 'LBA' 'SBH' 'SBD' 'SBA' 'WHH' 'WHD' 'WHA' 'SJH'
#  'SJD' 'SJA' 'VCH' 'VCD' 'VCA' 'BSH' 'BSD' 'BSA' 'Bb1X2' 'BbMxH' 'BbAvH'
#  'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5'
#  'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']
#
#  12
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'GBH' 'GBD' 'GBA' 'IWH'
#  'IWD' 'IWA' 'LBH' 'LBD' 'LBA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'SJH'
#  'SJD' 'SJA' 'VCH' 'VCD' 'VCA' 'BSH' 'BSD' 'BSA' 'Bb1X2' 'BbMxH' 'BbAvH'
#  'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5'
#  'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']
#
#  13
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'LBH'
#  'LBD' 'LBA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'SJH' 'SJD' 'SJA' 'VCH'
#  'VCD' 'VCA' 'Bb1X2' 'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA'
#  'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh'
#  'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']
#
#  14
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'LBH'
#  'LBD' 'LBA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'SJH' 'SJD' 'SJA' 'VCH'
#  'VCD' 'VCA' 'Bb1X2' 'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA'
#  'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh'
#  'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']
#
#  15
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'LBH'
#  'LBD' 'LBA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'Bb1X2'
#  'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5'
#  'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH'
#  'BbMxAHA' 'BbAvAHA']
#
#  16
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'LBH'
#  'LBD' 'LBA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'Bb1X2'
#  'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5'
#  'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH'
#  'BbMxAHA' 'BbAvAHA' 'PSCH' 'PSCD' 'PSCA']
#
#  17
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'LBH'
#  'LBD' 'LBA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'Bb1X2'
#  'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5'
#  'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH'
#  'BbMxAHA' 'BbAvAHA' 'PSCH' 'PSCD' 'PSCA']
#
#  18
# ['Div' 'Date' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'PSH'
#  'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'Bb1X2' 'BbMxH' 'BbAvH'
#  'BbMxD' 'BbAvD' 'BbMxA' 'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5'
#  'BbAv<2.5' 'BbAH' 'BbAHh' 'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA' 'PSCH'
#  'PSCD' 'PSCA']
#
#  19
# ['Div' 'Date' 'Time' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG'
#  'HTAG' 'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY'
#  'AY' 'HR' 'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD'
#  'IWA' 'PSH' 'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'MaxH' 'MaxD'
#  'MaxA' 'AvgH' 'AvgD' 'AvgA' 'B365>2.5' 'B365<2.5' 'P>2.5' 'P<2.5'
#  'Max>2.5' 'Max<2.5' 'Avg>2.5' 'Avg<2.5' 'AHh' 'B365AHH' 'B365AHA' 'PAHH'
#  'PAHA' 'MaxAHH' 'MaxAHA' 'AvgAHH' 'AvgAHA' 'B365CH' 'B365CD' 'B365CA'
#  'BWCH' 'BWCD' 'BWCA' 'IWCH' 'IWCD' 'IWCA' 'PSCH' 'PSCD' 'PSCA' 'WHCH'
#  'WHCD' 'WHCA' 'VCCH' 'VCCD' 'VCCA' 'MaxCH' 'MaxCD' 'MaxCA' 'AvgCH'
#  'AvgCD' 'AvgCA' 'B365C>2.5' 'B365C<2.5' 'PC>2.5' 'PC<2.5' 'MaxC>2.5'
#  'MaxC<2.5' 'AvgC>2.5' 'AvgC<2.5' 'AHCh' 'B365CAHH' 'B365CAHA' 'PCAHH'
#  'PCAHA' 'MaxCAHH' 'MaxCAHA' 'AvgCAHH' 'AvgCAHA']

# %%
arr = [y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18,y19,y20]
a = []
for i in range (20):
    a.append(arr[i][['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']])

print(a)
# Out:
# [         Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    19/08/00       Charlton       Man City     4     0   H     2     0   H
# 1    19/08/00        Chelsea       West Ham     4     2   H     1     0   H
# 2    19/08/00       Coventry  Middlesbrough     1     3   A     1     1   D
# 3    19/08/00          Derby    Southampton     2     2   D     1     2   A
# 4    19/08/00          Leeds        Everton     2     0   H     2     0   H
# ..        ...            ...            ...   ...   ...  ..   ...   ...  ..
# 375  19/05/01       Man City        Chelsea     1     2   A     1     1   D
# 376  19/05/01  Middlesbrough       West Ham     2     1   H     2     1   H
# 377  19/05/01      Newcastle    Aston Villa     3     0   H     2     0   H
# 378  19/05/01    Southampton        Arsenal     3     2   H     0     1   A
# 379  19/05/01      Tottenham     Man United     3     1   H     1     1   D
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    17  ...   14    4  13  12   6   6   1   2   0   0
# 1    17  ...   10    5  19  14   7   7   1   2   0   0
# 2     6  ...    3    9  15  21   8   4   5   3   1   0
# 3     6  ...    4    6  11  13   5   8   1   1   0   0
# 4    17  ...    8    6  21  20   6   4   1   3   0   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375   3  ...    1    3  22  18   8   7   4   2   0   0
# 376  19  ...    7    5  13  15   5   6   0   0   0   0
# 377   9  ...    5    1  10  14   5   1   0   5   1   1
# 378  11  ...    7    5  17  10   7   5   1   2   0   0
# 379   9  ...    3    6  13  15   3   6   0   2   0   0
#
# [380 rows x 21 columns],          Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    18/08/01     Charlton      Everton     1     2   A     0     0   D   8
# 1    18/08/01        Derby    Blackburn     2     1   H     1     0   H   7
# 2    18/08/01        Leeds  Southampton     2     0   H     0     0   D  16
# 3    18/08/01    Leicester       Bolton     0     5   A     0     4   A   6
# 4    18/08/01    Liverpool     West Ham     2     1   H     1     1   D   9
# ..        ...          ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  11/05/02    Liverpool      Ipswich     5     0   H     2     0   H  15
# 376  11/05/02   Man United     Charlton     0     0   D     0     0   D  13
# 377  11/05/02  Southampton    Newcastle     3     1   H     2     0   H   7
# 378  11/05/02   Sunderland        Derby     1     1   D     1     0   H  26
# 379  11/05/02     West Ham       Bolton     2     1   H     1     0   H  17
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    4    9  15  17   4   4   0   3   0   0
# 1    ...    3    4  14  15   4  10   1   0   0   0
# 2    ...    6    6  16  24  10   3   1   2   0   1
# 3    ...    1    8  21  17   3   5   4   3   0   0
# 4    ...    6    3  13  12   5   3   1   5   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    8    2  13   5   0   7   0   0   0   0
# 376  ...    6    6   8   7   7   4   2   0   0   0
# 377  ...    3    8  15  11   3   6   0   1   1   0
# 378  ...   12    3  11  14   4   2   0   1   0   0
# 379  ...   10    4   9  13   9   5   2   1   0   0
#
# [380 rows x 21 columns],            Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    17/08/2002   Blackburn   Sunderland     0     0   D     0     0   D  15
# 1    17/08/2002    Charlton      Chelsea     2     3   A     2     1   H   5
# 2    17/08/2002     Everton    Tottenham     2     2   D     1     0   H  13
# 3    17/08/2002      Fulham       Bolton     4     1   H     3     1   H  13
# 4    17/08/2002       Leeds     Man City     3     0   H     2     0   H  13
# ..          ...         ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  11/05/2003       Leeds  Aston Villa     3     1   H     1     1   D  11
# 376  11/05/2003    Man City  Southampton     0     1   A     0     1   A  17
# 377  11/05/2003  Sunderland      Arsenal     0     4   A     0     2   A   7
# 378  11/05/2003   Tottenham    Blackburn     0     4   A     0     2   A  11
# 379  11/05/2003   West Brom    Newcastle     2     2   D     0     1   A   8
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    5    3  14  11   9   1   1   2   0   0
# 1    ...    5   12  10  12   3   6   0   3   1   0
# 2    ...    9    5  18   4  10   5   1   1   0   0
# 3    ...    6    1  16  12   7   4   1   2   0   0
# 4    ...    8   10  13  13   2   7   1   1   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    5    6  18  14   1   8   0   1   0   0
# 376  ...    7    3  14  14  10   4   3   4   0   0
# 377  ...    3   13  16  12   6  10   1   0   0   0
# 378  ...    7    9   9  12   6   3   1   1   1   0
# 379  ...    3    9   9   8   2   8   0   0   0   0
#
# [380 rows x 21 columns],          Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    16/08/03     Arsenal        Everton     2     1   H     1     0   H  11
# 1    16/08/03  Birmingham      Tottenham     1     0   H     1     0   H  10
# 2    16/08/03   Blackburn         Wolves     5     1   H     2     0   H  25
# 3    16/08/03      Fulham  Middlesbrough     3     2   H     1     1   D  17
# 4    16/08/03   Leicester    Southampton     2     2   D     2     0   H  12
# ..        ...         ...            ...   ...   ...  ..   ...   ...  ..  ..
# 375  15/05/04     Chelsea          Leeds     1     0   H     1     0   H  19
# 376  15/05/04   Liverpool      Newcastle     1     1   D     0     1   A   8
# 377  15/05/04    Man City        Everton     5     1   H     3     0   H  13
# 378  15/05/04  Portsmouth  Middlesbrough     5     1   H     3     1   H  16
# 379  15/05/04      Wolves      Tottenham     0     2   A     0     1   A  18
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    5    7   8  15   6   9   1   3   1   1
# 1    ...    5    7  20  27   1   4   3   5   0   0
# 2    ...   13    5   8  14   6   2   1   1   0   0
# 3    ...    9    5  18  16   7   6   1   1   0   0
# 4    ...    7   10  27  15   2   7   3   1   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    9    0   5   9   9   2   0   0   0   0
# 376  ...    4    5  11  17   8   1   1   1   0   0
# 377  ...   11    0   5   8   7   3   1   1   0   0
# 378  ...   10    4  12   8   7   2   0   0   0   0
# 379  ...   10   12   6  11   5   3   1   1   1   0
#
# [380 rows x 21 columns],          Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    14/08/04    Aston Villa    Southampton     2     0   H     2     0   H
# 1    14/08/04      Blackburn      West Brom     1     1   D     0     1   A
# 2    14/08/04         Bolton       Charlton     4     1   H     2     0   H
# 3    14/08/04       Man City         Fulham     1     1   D     1     0   H
# 4    14/08/04  Middlesbrough      Newcastle     2     2   D     0     1   A
# ..        ...            ...            ...   ...   ...  ..   ...   ...  ..
# 375  15/05/05       Man City  Middlesbrough     1     1   D     0     1   A
# 376  15/05/05      Newcastle        Chelsea     1     1   D     1     1   D
# 377  15/05/05    Southampton     Man United     1     2   A     1     1   D
# 378  15/05/05      Tottenham      Blackburn     0     0   D     0     0   D
# 379  15/05/05      West Brom     Portsmouth     2     0   H     0     0   D
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    14  ...    5    2  14   9  12   6   0   0   0   0
# 1    12  ...    4    2  15  17   4   5   1   0   0   0
# 2    21  ...   11    5  10  12   9   5   1   1   0   0
# 3    12  ...    5    2  14  12   9   4   0   2   0   0
# 4    15  ...    8    4  16  13   6   7   3   1   0   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  10  ...    5    3  12  15  10   3   2   4   0   0
# 376   8  ...    4    7  11  17   6   4   4   4   0   0
# 377  11  ...    3    8  14  13   5   3   1   2   0   0
# 378  11  ...    7    8  10  14   5   7   2   2   0   0
# 379   9  ...    5    2  12  13   6   1   0   1   0   0
#
# [380 rows x 21 columns],          Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    13/08/05    Aston Villa         Bolton     2     2   D     2     2   D
# 1    13/08/05        Everton     Man United     0     2   A     0     1   A
# 2    13/08/05         Fulham     Birmingham     0     0   D     0     0   D
# 3    13/08/05       Man City      West Brom     0     0   D     0     0   D
# 4    13/08/05  Middlesbrough      Liverpool     0     0   D     0     0   D
# ..        ...            ...            ...   ...   ...  ..   ...   ...  ..
# 375  07/05/06         Fulham  Middlesbrough     1     0   H     0     0   D
# 376  07/05/06     Man United       Charlton     4     0   H     3     0   H
# 377  07/05/06      Newcastle        Chelsea     1     0   H     0     0   D
# 378  07/05/06     Portsmouth      Liverpool     1     3   A     0     0   D
# 379  07/05/06       West Ham      Tottenham     2     1   H     1     1   D
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     3  ...    2    6  14  16   7   8   0   2   0   0
# 1    10  ...    5    5  15  14   8   6   3   1   0   0
# 2    15  ...    7    4  12  13   6   6   1   2   0   0
# 3    15  ...    8    3  13  11   3   6   2   3   0   0
# 4     4  ...    2    7  17  11   5   0   2   3   1   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375   8  ...    3    3   8  12   8   4   0   1   0   0
# 376  20  ...   11    3   9   6   8   2   1   0   0   0
# 377  16  ...    8    5  17  14   3   7   4   2   1   0
# 378   6  ...    4    4   5  11   5   6   1   0   0   0
# 379  12  ...    7    6  17   7  11   4   1   0   0   0
#
# [380 rows x 21 columns],          Date          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    19/08/06           Arsenal  Aston Villa     1     1   D     0     0   D
# 1    19/08/06            Bolton    Tottenham     2     0   H     2     0   H
# 2    19/08/06           Everton      Watford     2     1   H     1     0   H
# 3    19/08/06         Newcastle        Wigan     2     1   H     1     0   H
# 4    19/08/06        Portsmouth    Blackburn     3     0   H     1     0   H
# ..        ...               ...          ...   ...   ...  ..   ...   ...  ..
# 375  13/05/07     Middlesbrough       Fulham     3     1   H     2     1   H
# 376  13/05/07        Portsmouth      Arsenal     0     0   D     0     0   D
# 377  13/05/07  Sheffield United        Wigan     1     2   A     1     2   A
# 378  13/05/07         Tottenham     Man City     2     1   H     2     1   H
# 379  13/05/07           Watford    Newcastle     1     1   D     0     1   A
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    19  ...   11    3  10  19  18   1   1   2   0   0
# 1     8  ...    6    6  19  22   6   3   0   1   0   0
# 2     6  ...    2    8  12  13   0   6   2   2   0   0
# 3     9  ...    8    9  17  20   4  11   1   2   0   0
# 4    21  ...   16    7  20  17   6   2   2   1   0   2
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  21  ...   10    5  11  12  10   3   1   0   0   0
# 376   9  ...    4    6  18  15   2   6   0   0   0   0
# 377   9  ...    5    3  11  15  10   3   3   5   0   1
# 378   8  ...    3    5  11  13   6   6   1   1   0   0
# 379  11  ...    2    1  13   6   8   5   2   4   0   0
#
# [380 rows x 21 columns],          Date       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    11/08/07    Aston Villa    Liverpool     1     2   A     0     1   A  10
# 1    11/08/07         Bolton    Newcastle     1     3   A     0     3   A  13
# 2    11/08/07          Derby   Portsmouth     2     2   D     1     1   D  12
# 3    11/08/07        Everton        Wigan     2     1   H     1     0   H  12
# 4    11/08/07  Middlesbrough    Blackburn     1     2   A     1     0   H  10
# ..        ...            ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  11/05/08     Portsmouth       Fulham     0     1   A     0     0   D  15
# 376  11/05/08     Sunderland      Arsenal     0     1   A     0     1   A  13
# 377  11/05/08      Tottenham    Liverpool     0     2   A     0     0   D   6
# 378  11/05/08       West Ham  Aston Villa     2     2   D     1     1   D  16
# 379  11/05/08          Wigan   Man United     0     2   A     0     1   A  15
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    6    7  18  11   4   2   4   2   0   0
# 1    ...    9    5  15  16   4   3   1   1   0   0
# 2    ...    5    6  14  17   6   6   1   2   0   0
# 3    ...    8    4   8  13   6   2   0   0   0   0
# 4    ...    6    4  16  16  13   3   3   4   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...   10    4  13  11   5   6   0   0   0   0
# 376  ...    5    8  14  12   3   4   1   1   0   0
# 377  ...    3   12  11   9   8   4   1   1   0   0
# 378  ...    8    8   9  21   7   8   2   2   0   0
# 379  ...    6    6  10   5   5  12   3   2   0   0
#
# [380 rows x 21 columns],          Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    16/08/08        Arsenal      West Brom     1     0   H     1     0   H
# 1    16/08/08         Bolton          Stoke     3     1   H     3     0   H
# 2    16/08/08        Everton      Blackburn     2     3   A     1     1   D
# 3    16/08/08           Hull         Fulham     2     1   H     1     1   D
# 4    16/08/08  Middlesbrough      Tottenham     2     1   H     0     0   D
# ..        ...            ...            ...   ...   ...  ..   ...   ...  ..
# 375  24/05/09      Liverpool      Tottenham     3     1   H     1     0   H
# 376  24/05/09       Man City         Bolton     1     0   H     1     0   H
# 377  24/05/09     Sunderland        Chelsea     2     3   A     0     0   D
# 378  24/05/09       West Ham  Middlesbrough     2     1   H     1     0   H
# 379  24/05/09          Wigan     Portsmouth     1     0   H     1     0   H
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    24  ...   14    4  11   8   7   5   0   0   0   0
# 1    14  ...    8    2  13  12   4   3   1   2   0   0
# 2    10  ...    5   11  11   9   3   5   2   2   0   0
# 3    11  ...    6    6  10   9   5   6   3   0   0   0
# 4    14  ...   10    5  11  12   7   9   1   2   0   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  20  ...    9    4  14   4   9   2   0   1   0   0
# 376  20  ...   12    4   8  10  15   9   0   0   0   0
# 377   8  ...    7    9   8   7   6   7   1   1   0   0
# 378  14  ...    8    6  14  10   4   5   0   1   0   0
# 379  19  ...   10    3   8  21   8   2   0   4   0   0
#
# [380 rows x 21 columns],          Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    15/08/09  Aston Villa       Wigan     0     2   A     0     1   A  11
# 1    15/08/09    Blackburn    Man City     0     2   A     0     1   A  17
# 2    15/08/09       Bolton  Sunderland     0     1   A     0     1   A  11
# 3    15/08/09      Chelsea        Hull     2     1   H     1     1   D  26
# 4    15/08/09      Everton     Arsenal     1     6   A     0     3   A   8
# ..        ...          ...         ...   ...   ...  ..   ...   ...  ..  ..
# 375  09/05/10      Everton  Portsmouth     1     0   H     0     0   D  21
# 376  09/05/10         Hull   Liverpool     0     0   D     0     0   D  11
# 377  09/05/10   Man United       Stoke     4     0   H     2     0   H  18
# 378  09/05/10     West Ham    Man City     1     1   D     1     1   D  12
# 379  09/05/10       Wolves  Sunderland     2     1   H     1     1   D  14
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    5    7  15  14   4   6   2   2   0   0
# 1    ...    9    5  12   9   5   4   2   1   0   0
# 2    ...    3   13  16  10   4   7   2   1   0   0
# 3    ...   12    3  13  15  12   4   1   2   0   0
# 4    ...    5    9  11  13   4   9   0   0   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...   13    4  12  11  14   1   0   0   0   0
# 376  ...    6    7  15  11   2   6   1   0   0   0
# 377  ...   13    4  10   4  10   2   2   0   0   0
# 378  ...    8    6  12   7   4   3   2   0   0   0
# 379  ...    7    5  11  19   4   1   1   2   0   2
#
# [380 rows x 21 columns],          Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    14/08/10  Aston Villa    West Ham     3     0   H     2     0   H  23
# 1    14/08/10    Blackburn     Everton     1     0   H     1     0   H   7
# 2    14/08/10       Bolton      Fulham     0     0   D     0     0   D  13
# 3    14/08/10      Chelsea   West Brom     6     0   H     2     0   H  18
# 4    14/08/10   Sunderland  Birmingham     2     2   D     1     0   H   6
# ..        ...          ...         ...   ...   ...  ..   ...   ...  ..  ..
# 375  22/05/11    Newcastle   West Brom     3     3   D     2     0   H  15
# 376  22/05/11        Stoke       Wigan     0     1   A     0     0   D  11
# 377  22/05/11    Tottenham  Birmingham     2     1   H     0     0   D  22
# 378  22/05/11     West Ham  Sunderland     0     3   A     0     1   A  17
# 379  22/05/11       Wolves   Blackburn     2     3   A     0     3   A  12
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...   11    2  15  15  16   7   1   2   0   0
# 1    ...    2   12  19  14   1   3   2   1   0   0
# 2    ...    9    7  12  13   4   8   1   3   0   0
# 3    ...   13    4  10  10   3   1   1   0   0   0
# 4    ...    2    7  13  10   3   6   3   3   1   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...   10    7   5   8   7   6   0   0   0   0
# 376  ...    5    9  10   9   5   3   1   4   0   0
# 377  ...   16    3   5  15   7   5   0   3   0   0
# 378  ...   12   12   7   8   4   6   0   2   0   0
# 379  ...    5   10  12   9   8   3   3   1   0   0
#
# [380 rows x 21 columns],          Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    13/08/11   Blackburn       Wolves     1     2   A     1     1   D  16
# 1    13/08/11      Fulham  Aston Villa     0     0   D     0     0   D  13
# 2    13/08/11   Liverpool   Sunderland     1     1   D     1     0   H  11
# 3    13/08/11   Newcastle      Arsenal     0     0   D     0     0   D   6
# 4    13/08/11         QPR       Bolton     0     4   A     0     1   A  13
# ..        ...         ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  13/05/12  Sunderland   Man United     0     1   A     0     1   A   6
# 376  13/05/12     Swansea    Liverpool     1     0   H     0     0   D  13
# 377  13/05/12   Tottenham       Fulham     2     0   H     1     0   H  15
# 378  13/05/12   West Brom      Arsenal     2     3   A     2     2   D  12
# 379  13/05/12       Wigan       Wolves     3     2   H     2     1   H  14
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    8    4  14  10  12   6   4   2   0   0
# 1    ...    9    1  10  18   2   3   2   4   0   0
# 2    ...    4    6  17  12   6   3   4   4   0   0
# 3    ...    1    4   9  11   2   5   3   5   0   1
# 4    ...    7    7   9  16   3   2   1   2   1   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    5    9  14  11   1   9   3   3   0   0
# 376  ...    8    9   5   5   6   5   1   1   0   0
# 377  ...    9    7   8  12   9   3   0   2   0   0
# 378  ...    8    8  12  10   9   5   0   1   0   0
# 379  ...   10    7  15   9   9   2   1   2   0   0
#
# [380 rows x 21 columns],          Date   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    18/08/12    Arsenal   Sunderland     0     0   D     0     0   D  14
# 1    18/08/12     Fulham      Norwich     5     0   H     2     0   H  11
# 2    18/08/12  Newcastle    Tottenham     2     1   H     0     0   D   6
# 3    18/08/12        QPR      Swansea     0     5   A     0     1   A  20
# 4    18/08/12    Reading        Stoke     1     1   D     0     1   A   9
# ..        ...        ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  19/05/13    Swansea       Fulham     0     3   A     0     1   A  19
# 376  19/05/13  Tottenham   Sunderland     1     0   H     0     0   D  23
# 377  19/05/13  West Brom   Man United     5     5   D     1     3   A  15
# 378  19/05/13   West Ham      Reading     4     2   H     2     0   H  21
# 379  19/05/13      Wigan  Aston Villa     2     2   D     2     1   H  12
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    4    2  12   8   7   0   0   0   0   0
# 1    ...    9    2  12  11   6   3   0   0   0   0
# 2    ...    4    6  12   8   3   5   2   2   0   0
# 3    ...   11    8  11  14   5   3   2   2   0   0
# 4    ...    3    3   9  14   4   3   2   4   0   1
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...   11    6  12   9   8   0   2   1   0   0
# 376  ...   19    4   6  12  14   1   1   3   0   1
# 377  ...    8    8  10   6   3   5   0   1   0   0
# 378  ...   12    7  14   8   6   4   2   1   0   0
# 379  ...    6    2   8  12   4   2   2   1   0   0
#
# [380 rows x 21 columns],          Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    17/08/13      Arsenal  Aston Villa     1     3   A     1     1   D  16
# 1    17/08/13    Liverpool        Stoke     1     0   H     1     0   H  26
# 2    17/08/13      Norwich      Everton     2     2   D     0     0   D   8
# 3    17/08/13   Sunderland       Fulham     0     1   A     0     0   D  20
# 4    17/08/13      Swansea   Man United     1     4   A     0     2   A  17
# ..        ...          ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  11/05/14      Norwich      Arsenal     0     2   A     0     0   D  11
# 376  11/05/14  Southampton   Man United     1     1   D     1     0   H  15
# 377  11/05/14   Sunderland      Swansea     1     3   A     0     2   A  20
# 378  11/05/14    Tottenham  Aston Villa     3     0   H     3     0   H  12
# 379  11/05/14    West Brom        Stoke     1     2   A     0     1   A  17
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    4    4  15  18   4   3   4   5   1   0
# 1    ...   11    4  11  11  12   6   1   1   0   0
# 2    ...    2    6  13  10   6   8   2   0   0   0
# 3    ...    3    1  14  14   6   1   0   3   0   0
# 4    ...    6    7  13  10   7   4   1   3   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    5    8   6   5   4   4   1   0   0   0
# 376  ...    6    2  16   5   6   2   3   2   0   0
# 377  ...    4    4  14  15   6   3   2   3   0   0
# 378  ...    6    1  11  11   5   1   1   0   0   0
# 379  ...    4    4   4   7  11   6   0   0   0   0
#
# [380 rows x 21 columns],          Date    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    16/08/14     Arsenal  Crystal Palace     2     1   H     1     1   D  14
# 1    16/08/14   Leicester         Everton     2     2   D     1     2   A  11
# 2    16/08/14  Man United         Swansea     1     2   A     0     1   A  14
# 3    16/08/14         QPR            Hull     0     1   A     0     0   D  19
# 4    16/08/14       Stoke     Aston Villa     0     1   A     0     0   D  12
# ..        ...         ...             ...   ...   ...  ..   ...   ...  ..  ..
# 375  24/05/15        Hull      Man United     0     0   D     0     0   D  16
# 376  24/05/15   Leicester             QPR     5     1   H     2     0   H  22
# 377  24/05/15    Man City     Southampton     2     0   H     1     0   H  15
# 378  24/05/15   Newcastle        West Ham     2     0   H     0     0   D  17
# 379  24/05/15       Stoke       Liverpool     6     1   H     5     0   H  15
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    6    2  13  19   9   3   2   2   0   1
# 1    ...    3    3  16  10   3   6   1   1   0   0
# 2    ...    5    4  14  20   4   0   2   4   0   0
# 3    ...    6    4  10  10   8   9   1   2   0   0
# 4    ...    2    2  14   9   2   8   0   3   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    6    1  12  15   8   1   2   2   0   1
# 376  ...    7    2   7   6   5   6   0   0   0   0
# 377  ...    6    4  13   8   8   4   1   1   0   0
# 378  ...    4    1   9   9   2   3   2   1   0   0
# 379  ...    9    4  13   4   3   9   4   2   0   0
#
# [380 rows x 21 columns],          Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0    08/08/15  Bournemouth  Aston Villa     0     1   A     0     0   D  11
# 1    08/08/15      Chelsea      Swansea     2     2   D     2     1   H  11
# 2    08/08/15      Everton      Watford     2     2   D     0     1   A  10
# 3    08/08/15    Leicester   Sunderland     4     2   H     3     0   H  19
# 4    08/08/15   Man United    Tottenham     1     0   H     1     0   H   9
# ..        ...          ...          ...   ...   ...  ..   ...   ...  ..  ..
# 375  15/05/16        Stoke     West Ham     2     1   H     0     1   A   7
# 376  15/05/16      Swansea     Man City     1     1   D     1     1   D   4
# 377  15/05/16      Watford   Sunderland     2     2   D     0     1   A  21
# 378  15/05/16    West Brom    Liverpool     1     1   D     1     1   D  13
# 379  17/05/16   Man United  Bournemouth     3     1   H     1     0   H  12
#
#      ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    ...    2    3  13  13   6   3   3   4   0   0
# 1    ...    3   10  15  16   4   8   1   3   1   0
# 2    ...    5    5   7  13   8   2   1   2   0   0
# 3    ...    8    5  13  17   6   3   2   4   0   0
# 4    ...    1    4  12  12   1   2   2   3   0   0
# ..   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  ...    4    7   8  12   4  10   3   1   0   0
# 376  ...    1    5   4  19   4   4   1   3   0   0
# 377  ...    6    4  11  10   7   4   1   0   0   0
# 378  ...    1    3  11  14   7   5   3   1   0   0
# 379  ...    5    0   9   8   7   1   1   0   0   0
#
# [380 rows x 21 columns],          Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    13/08/16         Burnley         Swansea     0     1   A     0     0   D
# 1    13/08/16  Crystal Palace       West Brom     0     1   A     0     0   D
# 2    13/08/16         Everton       Tottenham     1     1   D     1     0   H
# 3    13/08/16            Hull       Leicester     2     1   H     1     0   H
# 4    13/08/16        Man City      Sunderland     2     1   H     1     0   H
# ..        ...             ...             ...   ...   ...  ..   ...   ...  ..
# 375  21/05/17       Liverpool   Middlesbrough     3     0   H     1     0   H
# 376  21/05/17      Man United  Crystal Palace     2     0   H     2     0   H
# 377  21/05/17     Southampton           Stoke     0     1   A     0     0   D
# 378  21/05/17         Swansea       West Brom     2     1   H     0     1   A
# 379  21/05/17         Watford        Man City     0     5   A     0     4   A
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    10  ...    3    9  10  14   7   4   3   2   0   0
# 1    14  ...    4    3  12  15   3   6   2   2   0   0
# 2    12  ...    6    4  10  14   5   6   0   0   0   0
# 3    14  ...    5    5   8  17   5   3   2   2   0   0
# 4    16  ...    4    3  11  14   9   6   1   2   0   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  25  ...   10    3  13   8   3   3   0   1   0   0
# 376   9  ...    2    1  16  10   3   6   2   0   0   0
# 377  14  ...    6    3  12  10   4  10   2   4   0   0
# 378  12  ...    2    5   8  10   7   4   1   1   0   0
# 379   6  ...    3    9  12  10   4   5   1   0   0   0
#
# [380 rows x 21 columns],          Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    11/08/17         Arsenal     Leicester     4     3   H     2     2   D
# 1    12/08/17        Brighton      Man City     0     2   A     0     0   D
# 2    12/08/17         Chelsea       Burnley     2     3   A     0     3   A
# 3    12/08/17  Crystal Palace  Huddersfield     0     3   A     0     2   A
# 4    12/08/17         Everton         Stoke     1     0   H     1     0   H
# ..        ...             ...           ...   ...   ...  ..   ...   ...  ..
# 375  13/05/18       Newcastle       Chelsea     3     0   H     1     0   H
# 376  13/05/18     Southampton      Man City     0     1   A     0     0   D
# 377  13/05/18         Swansea         Stoke     1     2   A     1     2   A
# 378  13/05/18       Tottenham     Leicester     5     4   H     1     2   A
# 379  13/05/18        West Ham       Everton     3     1   H     1     0   H
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0    27  ...   10    3   9  12   9   4   0   1   0   0
# 1     6  ...    2    4   6   9   3  10   0   2   0   0
# 2    19  ...    6    5  16  11   8   5   3   3   2   0
# 3    14  ...    4    6   7  19  12   9   1   3   0   0
# 4     9  ...    4    1  13  10   6   7   1   1   0   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375  16  ...    6    2  11  10   4   2   0   1   0   0
# 376   8  ...    3    2   8  10   1  12   3   1   0   0
# 377  26  ...   11    5  12   9   6   0   1   2   0   0
# 378  14  ...    6    9   9  13   4   4   1   2   0   0
# 379  15  ...    4    7  10  13   6   6   0   1   0   0
#
# [380 rows x 21 columns],          Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    10/08/18    Man United       Leicester     2     1   H     1     0   H
# 1    11/08/18   Bournemouth         Cardiff     2     0   H     1     0   H
# 2    11/08/18        Fulham  Crystal Palace     0     2   A     0     1   A
# 3    11/08/18  Huddersfield         Chelsea     0     3   A     0     2   A
# 4    11/08/18     Newcastle       Tottenham     1     2   A     1     2   A
# ..        ...           ...             ...   ...   ...  ..   ...   ...  ..
# 155  08/12/18     Leicester       Tottenham     0     2   A     0     1   A
# 156  08/12/18    Man United          Fulham     4     1   H     3     0   H
# 157  08/12/18      West Ham  Crystal Palace     3     2   H     0     1   A
# 158  09/12/18     Newcastle          Wolves     1     2   A     1     1   D
# 159  10/12/18       Everton         Watford     2     2   D     1     0   H
#
#      HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     8  ...    6    4  11   8   2   5   2   1   0   0
# 1    12  ...    4    1  11   9   7   4   1   1   0   0
# 2    15  ...    6    9   9  11   5   5   1   2   0   0
# 3     6  ...    1    4   9   8   2   5   2   1   0   0
# 4    15  ...    2    5  11  12   3   5   2   2   0   0
# ..   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 155  11  ...    3    2  12   7   6   5   3   1   0   0
# 156  20  ...   11    4  11  15  10   3   1   1   0   1
# 157  13  ...    6    4  10   8   5   3   1   2   0   0
# 158  12  ...    4    6  10  17   4   6   2   5   1   0
# 159  12  ...    5    3  13  13   6   6   1   1   0   0
#
# [160 rows x 21 columns],            Date        HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    09/08/2019       Liverpool           Norwich     4     1   H     4     0
# 1    10/08/2019        West Ham          Man City     0     5   A     0     1
# 2    10/08/2019     Bournemouth  Sheffield United     1     1   D     0     0
# 3    10/08/2019         Burnley       Southampton     3     0   H     0     0
# 4    10/08/2019  Crystal Palace           Everton     0     0   D     0     0
# ..          ...             ...               ...   ...   ...  ..   ...   ...
# 255  15/02/2020         Norwich         Liverpool     0     1   A     0     0
# 256  16/02/2020     Aston Villa         Tottenham     2     3   A     1     2
# 257  16/02/2020         Arsenal         Newcastle     4     0   H     0     0
# 258  17/02/2020         Chelsea        Man United     0     2   A     0     1
# 259  19/02/2020        Man City          West Ham     2     0   H     1     0
#
#     HTR  HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     H  15  ...    7    5   9   9  11   2   0   2   0   0
# 1     A   5  ...    3    9   6  13   1   1   2   2   0   0
# 2     D  13  ...    3    3  10  19   3   4   2   1   0   0
# 3     D  10  ...    4    3   6  12   2   7   0   0   0   0
# 4     D   6  ...    2    3  16  14   6   2   2   1   0   1
# ..   ..  ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 255   D   5  ...    1    6   5  11   2   7   1   2   0   0
# 256   A  18  ...    4   10  12  10  12   7   2   0   0   0
# 257   D  15  ...    7    2  15   9   5   6   2   0   0   0
# 258   A  17  ...    1    3  11  11   9   8   4   3   0   0
# 259   H  20  ...    7    0   5   7   6   1   0   1   0   0
#
# [260 rows x 21 columns]]

# %%
y1
# Out:
#     Div      Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  19/08/00       Charlton       Man City     4     0   H     2     0
# 1    E0  19/08/00        Chelsea       West Ham     4     2   H     1     0
# 2    E0  19/08/00       Coventry  Middlesbrough     1     3   A     1     1
# 3    E0  19/08/00          Derby    Southampton     2     2   D     1     2
# 4    E0  19/08/00          Leeds        Everton     2     0   H     2     0
# ..   ..       ...            ...            ...   ...   ...  ..   ...   ...
# 375  E0  19/05/01       Man City        Chelsea     1     2   A     1     1
# 376  E0  19/05/01  Middlesbrough       West Ham     2     1   H     2     1
# 377  E0  19/05/01      Newcastle    Aston Villa     3     0   H     2     0
# 378  E0  19/05/01    Southampton        Arsenal     3     2   H     0     1
# 379  E0  19/05/01      Tottenham     Man United     3     1   H     1     1
#
#     HTR  ...  HC AC  HF  AF  HO  AO  HY  AY  HR  AR
# 0     H  ...   6  6  13  12   8   6   1   2   0   0
# 1     H  ...   7  7  19  14   2   3   1   2   0   0
# 2     D  ...   8  4  15  21   1   3   5   3   1   0
# 3     A  ...   5  8  11  13   0   2   1   1   0   0
# 4     H  ...   6  4  21  20   6   1   1   3   0   0
# ..   ..  ...  .. ..  ..  ..  ..  ..  ..  ..  ..  ..
# 375   D  ...   8  7  22  18   2   2   4   2   0   0
# 376   H  ...   5  6  13  15   5   2   0   0   0   0
# 377   H  ...   5  1  10  14   2   4   0   5   1   1
# 378   A  ...   7  5  17  10   3   2   1   2   0   0
# 379   D  ...   3  6  13  15   3   2   0   2   0   0
#
# [380 rows x 28 columns]

# %%
playing_stat = a[0]
for j in range(0,20):
    playing_stat = pd.concat([playing_stat,a[j]],ignore_index=True)

playing_stat
# Out:
#             Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0       19/08/00     Charlton       Man City     4     0   H     2     0   H
# 1       19/08/00      Chelsea       West Ham     4     2   H     1     0   H
# 2       19/08/00     Coventry  Middlesbrough     1     3   A     1     1   D
# 3       19/08/00        Derby    Southampton     2     2   D     1     2   A
# 4       19/08/00        Leeds        Everton     2     0   H     2     0   H
# ...          ...          ...            ...   ...   ...  ..   ...   ...  ..
# 7635  15/02/2020      Norwich      Liverpool     0     1   A     0     0   D
# 7636  16/02/2020  Aston Villa      Tottenham     2     3   A     1     2   A
# 7637  16/02/2020      Arsenal      Newcastle     4     0   H     0     0   D
# 7638  17/02/2020      Chelsea     Man United     0     2   A     0     1   A
# 7639  19/02/2020     Man City       West Ham     2     0   H     1     0   H
#
#       HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     17  ...   14    4  13  12   6   6   1   2   0   0
# 1     17  ...   10    5  19  14   7   7   1   2   0   0
# 2      6  ...    3    9  15  21   8   4   5   3   1   0
# 3      6  ...    4    6  11  13   5   8   1   1   0   0
# 4     17  ...    8    6  21  20   6   4   1   3   0   0
# ...   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 7635   5  ...    1    6   5  11   2   7   1   2   0   0
# 7636  18  ...    4   10  12  10  12   7   2   0   0   0
# 7637  15  ...    7    2  15   9   5   6   2   0   0   0
# 7638  17  ...    1    3  11  11   9   8   4   3   0   0
# 7639  20  ...    7    0   5   7   6   1   0   1   0   0
#
# [7640 rows x 21 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(playing_stat['FTR'])
print(integer_encoded)

playing_stat['FTR']= integer_encoded
playing_stat
# Out:
# [2 2 0 ... 2 0 2]
#             Date     HomeTeam       AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG HTR  \
# 0       19/08/00     Charlton       Man City     4     0    2     2     0   H
# 1       19/08/00      Chelsea       West Ham     4     2    2     1     0   H
# 2       19/08/00     Coventry  Middlesbrough     1     3    0     1     1   D
# 3       19/08/00        Derby    Southampton     2     2    1     1     2   A
# 4       19/08/00        Leeds        Everton     2     0    2     2     0   H
# ...          ...          ...            ...   ...   ...  ...   ...   ...  ..
# 7635  15/02/2020      Norwich      Liverpool     0     1    0     0     0   D
# 7636  16/02/2020  Aston Villa      Tottenham     2     3    0     1     2   A
# 7637  16/02/2020      Arsenal      Newcastle     4     0    2     0     0   D
# 7638  17/02/2020      Chelsea     Man United     0     2    0     0     1   A
# 7639  19/02/2020     Man City       West Ham     2     0    2     1     0   H
#
#       HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     17  ...   14    4  13  12   6   6   1   2   0   0
# 1     17  ...   10    5  19  14   7   7   1   2   0   0
# 2      6  ...    3    9  15  21   8   4   5   3   1   0
# 3      6  ...    4    6  11  13   5   8   1   1   0   0
# 4     17  ...    8    6  21  20   6   4   1   3   0   0
# ...   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 7635   5  ...    1    6   5  11   2   7   1   2   0   0
# 7636  18  ...    4   10  12  10  12   7   2   0   0   0
# 7637  15  ...    7    2  15   9   5   6   2   0   0   0
# 7638  17  ...    1    3  11  11   9   8   4   3   0   0
# 7639  20  ...    7    0   5   7   6   1   0   1   0   0
#
# [7640 rows x 21 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(playing_stat['HomeTeam'])
print(integer_encoded)



playing_stat['HomeTeam']= integer_encoded

playing_stat
# Out:
# [11 12 13 ...  0 12 24]
#             Date  HomeTeam       AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG HTR  \
# 0       19/08/00        11       Man City     4     0    2     2     0   H
# 1       19/08/00        12       West Ham     4     2    2     1     0   H
# 2       19/08/00        13  Middlesbrough     1     3    0     1     1   D
# 3       19/08/00        15    Southampton     2     2    1     1     2   A
# 4       19/08/00        21        Everton     2     0    2     2     0   H
# ...          ...       ...            ...   ...   ...  ...   ...   ...  ..
# 7635  15/02/2020        29      Liverpool     0     1    0     0     0   D
# 7636  16/02/2020         1      Tottenham     2     3    0     1     2   A
# 7637  16/02/2020         0      Newcastle     4     0    2     0     0   D
# 7638  17/02/2020        12     Man United     0     2    0     0     1   A
# 7639  19/02/2020        24       West Ham     2     0    2     1     0   H
#
#       HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     17  ...   14    4  13  12   6   6   1   2   0   0
# 1     17  ...   10    5  19  14   7   7   1   2   0   0
# 2      6  ...    3    9  15  21   8   4   5   3   1   0
# 3      6  ...    4    6  11  13   5   8   1   1   0   0
# 4     17  ...    8    6  21  20   6   4   1   3   0   0
# ...   ..  ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 7635   5  ...    1    6   5  11   2   7   1   2   0   0
# 7636  18  ...    4   10  12  10  12   7   2   0   0   0
# 7637  15  ...    7    2  15   9   5   6   2   0   0   0
# 7638  17  ...    1    3  11  11   9   8   4   3   0   0
# 7639  20  ...    7    0   5   7   6   1   0   1   0   0
#
# [7640 rows x 21 columns]

# %%
x22=pd.DataFrame(playing_stat['HomeTeam'])
x22['labels']=integer_encoded

x22['AwayTeam']=playing_stat['AwayTeam']
x22.head(20)
# Out:
#     HomeTeam  labels       AwayTeam
# 0         11      11       Man City
# 1         12      12       West Ham
# 2         13      13  Middlesbrough
# 3         15      15    Southampton
# 4         21      21        Everton
# 5         22      22    Aston Villa
# 6         23      23       Bradford
# 7         36      36        Arsenal
# 8         38      38        Ipswich
# 9         25      25      Newcastle
# 10         0       0      Liverpool
# 11         7       7        Chelsea
# 12        20      20     Man United
# 13        27      27      Tottenham
# 14        16      16       Charlton
# 15        24      24     Sunderland
# 16        28      28          Derby
# 17        34      34       Coventry
# 18        41      41      Leicester
# 19         0       0       Charlton

# %%
integer_encoded1 = label_encoder.fit_transform(playing_stat['AwayTeam'])
x22['label2']=integer_encoded1
x22

#THIS IS NOT USED IN CODE: THIS IS TO SHOW HOW ENCODING IS DONE
# Out:
#       HomeTeam  labels       AwayTeam  label2
# 0           11      11       Man City      24
# 1           12      12       West Ham      41
# 2           13      13  Middlesbrough      27
# 3           15      15    Southampton      34
# 4           21      21        Everton      16
# ...        ...     ...            ...     ...
# 7635        29      29      Liverpool      23
# 7636         1       1      Tottenham      38
# 7637         0       0      Newcastle      28
# 7638        12      12     Man United      25
# 7639        24      24       West Ham      41
#
# [7640 rows x 4 columns]

# %%
integer_encoded = label_encoder.fit_transform(playing_stat['AwayTeam'])
playing_stat['AwayTeam']= integer_encoded
playing_stat
# Out:
#             Date  HomeTeam  AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG HTR  HS  \
# 0       19/08/00        11        24     4     0    2     2     0   H  17
# 1       19/08/00        12        41     4     2    2     1     0   H  17
# 2       19/08/00        13        27     1     3    0     1     1   D   6
# 3       19/08/00        15        34     2     2    1     1     2   A   6
# 4       19/08/00        21        16     2     0    2     2     0   H  17
# ...          ...       ...       ...   ...   ...  ...   ...   ...  ..  ..
# 7635  15/02/2020        29        23     0     1    0     0     0   D   5
# 7636  16/02/2020         1        38     2     3    0     1     2   A  18
# 7637  16/02/2020         0        28     4     0    2     0     0   D  15
# 7638  17/02/2020        12        25     0     2    0     0     1   A  17
# 7639  19/02/2020        24        41     2     0    2     1     0   H  20
#
#       ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     ...   14    4  13  12   6   6   1   2   0   0
# 1     ...   10    5  19  14   7   7   1   2   0   0
# 2     ...    3    9  15  21   8   4   5   3   1   0
# 3     ...    4    6  11  13   5   8   1   1   0   0
# 4     ...    8    6  21  20   6   4   1   3   0   0
# ...   ...  ...  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 7635  ...    1    6   5  11   2   7   1   2   0   0
# 7636  ...    4   10  12  10  12   7   2   0   0   0
# 7637  ...    7    2  15   9   5   6   2   0   0   0
# 7638  ...    1    3  11  11   9   8   4   3   0   0
# 7639  ...    7    0   5   7   6   1   0   1   0   0
#
# [7640 rows x 21 columns]

# %%
sns.heatmap(playing_stat.corr())

#FTHG, HS, HST, AR, HC, AF, AY

#FTAG,AST

# %%
y=playing_stat['FTR']
x=playing_stat[['HomeTeam','AwayTeam','HS', 'HST', 'AR', 'HC', 'AF','AY']]

x
# Out:
#       HomeTeam  AwayTeam  HS  HST  AR  HC  AF  AY
# 0           11        24  17   14   0   6  12   2
# 1           12        41  17   10   0   7  14   2
# 2           13        27   6    3   0   8  21   3
# 3           15        34   6    4   0   5  13   1
# 4           21        16  17    8   0   6  20   3
# ...        ...       ...  ..  ...  ..  ..  ..  ..
# 7635        29        23   5    1   0   2  11   2
# 7636         1        38  18    4   0  12  10   0
# 7637         0        28  15    7   0   5   9   0
# 7638        12        25  17    1   0   9  11   3
# 7639        24        41  20    7   0   6   7   1
#
# [7640 rows x 8 columns]

# %%
y
# Out:
# 0       2
# 1       2
# 2       0
# 3       1
# 4       2
#        ..
# 7635    0
# 7636    0
# 7637    2
# 7638    0
# 7639    2
# Name: FTR, Length: 7640, dtype: int32

# %%
import sklearn
from sklearn.model_selection import train_test_split
# Shuffle and split the dataset into training and testing set.
train_X, test_X, train_Y, test_Y = train_test_split(x, y, 
                                                    test_size = 1000,
                                                    random_state = 2,
                                                    stratify = y)

print(test_X)
# Out:
#       HomeTeam  AwayTeam  HS  HST  AR  HC  AF  AY
# 4700         5         1  17   12   0   6   7   2
# 846         17        20   7    3   0   3  17   3
# 191          7        36  11    3   0   9  17   0
# 4334        24         5  19   10   0   8  18   2
# 3452        24        12  13    7   1   8  10   1
# ...        ...       ...  ..  ...  ..  ..  ..  ..
# 4156        12        35  29   18   0   7  12   3
# 4099         3        12   8    4   0   3   9   1
# 3222        16         5  18   10   0   7  18   3
# 5445        41        17  23   12   0   6   8   2
# 6153        14        40  21    8   0   8  13   3
#
# [1000 rows x 8 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

def KNN_classifier(train_X,train_Y,test_X,test_Y):
    
    neigh = KNeighborsClassifier(n_neighbors=2)
    neigh.fit(train_X, train_Y)
    trainAccuracy = neigh.score(train_X,train_Y)
    y_pred = neigh.predict(test_X)
    accuracy = metrics.accuracy_score(test_Y,y_pred)
    return accuracy,trainAccuracy
    


def NaiveBayes_classifier(train_X,train_Y,test_X,test_Y):
    
    gnb = GaussianNB()
    gnb.fit(train_X, train_Y)
    trainAccuracy = gnb.score(train_X,train_Y)
    y_pred = gnb.predict(test_X)
    accuracy = metrics.accuracy_score(test_Y,y_pred)
    return accuracy,trainAccuracy

import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split, GridSearchCV

def SVM(train_X,train_Y,test_X,test_Y):
    clf = svm.SVC(kernel='linear')
    clf.fit(train_X, train_Y)
    # Plot decision function on training and test data
    #plot_decision_function(train_X, train_Y, test_X, test_Y, clf)
    clf_predictions = clf.predict(test_X)
    print("Accuracy: {}%".format(clf.score(test_X, test_Y) * 100 ))

# %%
# table = pd.DataFrame(columns=('Team','HGS','AGS','HAS','AAS','HGC','AGC','HDS','ADS'))

# avg_home_scored = playing_stat.FTHG.sum() / 7260.0
# avg_away_scored = playing_stat.FTAG.sum() / 7260.0
# avg_home_conceded = avg_away_scored
# avg_away_conceded = avg_home_scored
# print(avg_home_scored , avg_away_scored)

KNN_classifier(train_X,train_Y,test_X,test_Y)
# Out:
# (0.384, 0.7375)

# %%
from sklearn.naive_bayes import GaussianNB

NaiveBayes_classifier(train_X,train_Y,test_X,test_Y)
# Out:
# (0.464, 0.4733433734939759)

# %%
SVM(train_X,train_Y,test_X,test_Y)
# Out:
# Accuracy: 50.2%

# %%
x1= playing_stat[['HS', 'HST', 'AR', 'HC', 'AF','AY']]
import sklearn
from sklearn.model_selection import train_test_split
# Shuffle and split the dataset into training and testing set.
train_X, test_X, train_Y, test_Y = train_test_split(x1, y, 
                                                    test_size = 1000,
                                                    random_state = 2,
                                                    stratify = y)
print(KNN_classifier(train_X,train_Y,test_X,test_Y))
print(NaiveBayes_classifier(train_X,train_Y,test_X,test_Y))
print(SVM(train_X,train_Y,test_X,test_Y))
# Out:
# (0.387, 0.7245481927710843)
# (0.456, 0.4724397590361446)
# Accuracy: 51.300000000000004%
# None
